# %%
import os
from ultralytics import YOLO
import cv2
import xgboost as xgb
import pandas as pd

def detect_shoplifting(video_path):
    model_yolo = YOLO(r"D:\Final year project\yolo version project\best.pt")
    model = xgb.Booster()
    model.load_model(r"D:\Final year project\yolo version project\model_weights.json")

    cap = cv2.VideoCapture(video_path)

    print('Total Frame', cap.get(cv2.CAP_PROP_FRAME_COUNT))

    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    # Define the codec and create VideoWriter object
    fourcc = cv2.VideoWriter_fourcc('F', 'M', 'P', '4')
    
    # Generate a unique output path
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    output_path = fr"D:\Final year project\yolo version project\output video\{video_name}_output.mp4"
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    frame_tot = 0

    while cap.isOpened():
        success, frame = cap.read()

        if success:
            results = model_yolo(frame, verbose=False)

            # Visualize the results on the frame
            annotated_frame = results[0].plot(boxes=False)

            for r in results:
                bound_box = r.boxes.xyxy
                conf = r.boxes.conf.tolist()
                keypoints = r.keypoints.xyn.tolist()

                print(f'Frame {frame_tot}: Detected {len(bound_box)} bounding boxes')

                for index, box in enumerate(bound_box):
                    if conf[index] > 0.75:
                        x1, y1, x2, y2 = box.tolist()
                        data = {}

                        # Initialize the x and y lists for each possible key
                        for j in range(len(keypoints[index])):
                            data[f'x{j}'] = keypoints[index][j][0]
                            data[f'y{j}'] = keypoints[index][j][1]

                        # print(f'Bounding Box {index}: {data}')
                        df = pd.DataFrame(data, index=[0])
                        dmatrix = xgb.DMatrix(df)
                        cut = model.predict(dmatrix)
                        binary_predictions = (cut > 0.5).astype(int)
                        print(f'Prediction: {binary_predictions}')

                        if binary_predictions == 0:
                            conf_text = f'Suspicious ({conf[index]:.2f})'
                            cv2.rectangle(annotated_frame, (int(x1), int(y1)), (int(x2), int(y2)), (255, 7, 58), 2)
                            cv2.putText(annotated_frame, conf_text, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_DUPLEX, 1.0, (255, 7, 58), 2)
                        if binary_predictions == 1:
                            conf_text = f'Normal ({conf[index]:.2f})'
                            cv2.rectangle(annotated_frame, (int(x1), int(y1)), (int(x2), int(y2)), (57, 255, 20), 2)
                            cv2.putText(annotated_frame, conf_text, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_DUPLEX, 1.0, (57, 255, 20), 2)


            cv2.imshow('Frame', annotated_frame)

            out.write(annotated_frame)
            frame_tot += 1
            print('Processed Frame:', frame_tot)

            if cv2.waitKey(1) & 0xFF == ord("q"):
                break
        else:
            break

    cap.release()
    out.release()
    cv2.destroyAllWindows()

# Example usage:
video_path = r"D:\Final year project\yolo version project\Test\istockphoto-668181452-640_adpp_is.mp4"
detect_shoplifting(video_path)
# Out:
# Total Frame 401.0
# Frame 0: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 1
# Frame 1: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 2
# Frame 2: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 3
# Frame 3: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 4
# Frame 4: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 5
# Frame 5: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 6
# Frame 6: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 7
# Frame 7: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 8
# Frame 8: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 9
# Frame 9: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 10
# Frame 10: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 11
# Frame 11: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 12
# Frame 12: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 13
# Frame 13: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 14
# Frame 14: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 15
# Frame 15: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 16
# Frame 16: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 17
# Frame 17: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 18
# Frame 18: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 19
# Frame 19: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 20
# Frame 20: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 21
# Frame 21: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 22
# Frame 22: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 23
# Frame 23: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 24
# Frame 24: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 25
# Frame 25: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 26
# Frame 26: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 27
# Frame 27: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 28
# Frame 28: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 29
# Frame 29: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 30
# Frame 30: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 31
# Frame 31: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 32
# Frame 32: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 33
# Frame 33: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 34
# Frame 34: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 35
# Frame 35: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 36
# Frame 36: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 37
# Frame 37: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 38
# Frame 38: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 39
# Frame 39: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 40
# Frame 40: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 41
# Frame 41: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 42
# Frame 42: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 43
# Frame 43: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 44
# Frame 44: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 45
# Frame 45: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 46
# Frame 46: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 47
# Frame 47: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 48
# Frame 48: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 49
# Frame 49: Detected 3 bounding boxes
# Prediction: [1]
# Processed Frame: 50
# Frame 50: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 51
# Frame 51: Detected 3 bounding boxes
# Prediction: [1]
# Processed Frame: 52
# Frame 52: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 53
# Frame 53: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 54
# Frame 54: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 55
# Frame 55: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 56
# Frame 56: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 57
# Frame 57: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 58
# Frame 58: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 59
# Frame 59: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 60
# Frame 60: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 61
# Frame 61: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 62
# Frame 62: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 63
# Frame 63: Detected 1 bounding boxes
# Prediction: [0]
# Processed Frame: 64
# Frame 64: Detected 1 bounding boxes
# Prediction: [0]
# Processed Frame: 65
# Frame 65: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 66
# Frame 66: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 67
# Frame 67: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 68
# Frame 68: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 69
# Frame 69: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 70
# Frame 70: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 71
# Frame 71: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 72
# Frame 72: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 73
# Frame 73: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 74
# Frame 74: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 75
# Frame 75: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 76
# Frame 76: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 77
# Frame 77: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 78
# Frame 78: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 79
# Frame 79: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 80
# Frame 80: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 81
# Frame 81: Detected 3 bounding boxes
# Prediction: [1]
# Processed Frame: 82
# Frame 82: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 83
# Frame 83: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 84
# Frame 84: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 85
# Frame 85: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 86
# Frame 86: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 87
# Frame 87: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 88
# Frame 88: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 89
# Frame 89: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 90
# Frame 90: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 91
# Frame 91: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 92
# Frame 92: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 93
# Frame 93: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 94
# Frame 94: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 95
# Frame 95: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 96
# Frame 96: Detected 4 bounding boxes
# Prediction: [0]
# Processed Frame: 97
# Frame 97: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 98
# Frame 98: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 99
# Frame 99: Detected 4 bounding boxes
# Prediction: [0]
# Processed Frame: 100
# Frame 100: Detected 4 bounding boxes
# Prediction: [0]
# Processed Frame: 101
# Frame 101: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 102
# Frame 102: Detected 4 bounding boxes
# Prediction: [0]
# Processed Frame: 103
# Frame 103: Detected 3 bounding boxes
# Prediction: [1]
# Processed Frame: 104
# Frame 104: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 105
# Frame 105: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 106
# Frame 106: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 107
# Frame 107: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 108
# Frame 108: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 109
# Frame 109: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 110
# Frame 110: Detected 1 bounding boxes
# Prediction: [0]
# Processed Frame: 111
# Frame 111: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 112
# Frame 112: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 113
# Frame 113: Detected 1 bounding boxes
# Prediction: [0]
# Processed Frame: 114
# Frame 114: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 115
# Frame 115: Detected 1 bounding boxes
# Prediction: [0]
# Processed Frame: 116
# Frame 116: Detected 1 bounding boxes
# Prediction: [0]
# Processed Frame: 117
# Frame 117: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 118
# Frame 118: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 119
# Frame 119: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 120
# Frame 120: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 121
# Frame 121: Detected 1 bounding boxes
# Prediction: [0]
# Processed Frame: 122
# Frame 122: Detected 0 bounding boxes
# Processed Frame: 123
# Frame 123: Detected 0 bounding boxes
# Processed Frame: 124
# Frame 124: Detected 0 bounding boxes
# Processed Frame: 125
# Frame 125: Detected 0 bounding boxes
# Processed Frame: 126
# Frame 126: Detected 0 bounding boxes
# Processed Frame: 127
# Frame 127: Detected 0 bounding boxes
# Processed Frame: 128
# Frame 128: Detected 0 bounding boxes
# Processed Frame: 129
# Frame 129: Detected 0 bounding boxes
# Processed Frame: 130
# Frame 130: Detected 1 bounding boxes
# Processed Frame: 131
# Frame 131: Detected 3 bounding boxes
# Processed Frame: 132
# Frame 132: Detected 3 bounding boxes
# Processed Frame: 133
# Frame 133: Detected 3 bounding boxes
# Prediction: [1]
# Processed Frame: 134
# Frame 134: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 135
# Frame 135: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 136
# Frame 136: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 137
# Frame 137: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 138
# Frame 138: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 139
# Frame 139: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 140
# Frame 140: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 141
# Frame 141: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 142
# Frame 142: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 143
# Frame 143: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 144
# Frame 144: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 145
# Frame 145: Detected 1 bounding boxes
# Prediction: [0]
# Processed Frame: 146
# Frame 146: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 147
# Frame 147: Detected 3 bounding boxes
# Prediction: [1]
# Processed Frame: 148
# Frame 148: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 149
# Frame 149: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 150
# Frame 150: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 151
# Frame 151: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 152
# Frame 152: Detected 3 bounding boxes
# Prediction: [1]
# Processed Frame: 153
# Frame 153: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 154
# Frame 154: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 155
# Frame 155: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 156
# Frame 156: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 157
# Frame 157: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 158
# Frame 158: Detected 4 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 159
# Frame 159: Detected 3 bounding boxes
# Prediction: [1]
# Processed Frame: 160
# Frame 160: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 161
# Frame 161: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 162
# Frame 162: Detected 3 bounding boxes
# Prediction: [1]
# Processed Frame: 163
# Frame 163: Detected 4 bounding boxes
# Prediction: [0]
# Processed Frame: 164
# Frame 164: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 165
# Frame 165: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 166
# Frame 166: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 167
# Frame 167: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 168
# Frame 168: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 169
# Frame 169: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 170
# Frame 170: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 171
# Frame 171: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 172
# Frame 172: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 173
# Frame 173: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 174
# Frame 174: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 175
# Frame 175: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 176
# Frame 176: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 177
# Frame 177: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 178
# Frame 178: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 179
# Frame 179: Detected 4 bounding boxes
# Prediction: [0]
# Processed Frame: 180
# Frame 180: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 181
# Frame 181: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 182
# Frame 182: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 183
# Frame 183: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 184
# Frame 184: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 185
# Frame 185: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 186
# Frame 186: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 187
# Frame 187: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 188
# Frame 188: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 189
# Frame 189: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 190
# Frame 190: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 191
# Frame 191: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 192
# Frame 192: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 193
# Frame 193: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 194
# Frame 194: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 195
# Frame 195: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 196
# Frame 196: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 197
# Frame 197: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 198
# Frame 198: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 199
# Frame 199: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 200
# Frame 200: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 201
# Frame 201: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 202
# Frame 202: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 203
# Frame 203: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 204
# Frame 204: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 205
# Frame 205: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 206
# Frame 206: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 207
# Frame 207: Detected 3 bounding boxes
# Processed Frame: 208
# Frame 208: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 209
# Frame 209: Detected 3 bounding boxes
# Processed Frame: 210
# Frame 210: Detected 2 bounding boxes
# Processed Frame: 211
# Frame 211: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 212
# Frame 212: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 213
# Frame 213: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 214
# Frame 214: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 215
# Frame 215: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 216
# Frame 216: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 217
# Frame 217: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 218
# Frame 218: Detected 3 bounding boxes
# Prediction: [1]
# Processed Frame: 219
# Frame 219: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 220
# Frame 220: Detected 3 bounding boxes
# Processed Frame: 221
# Frame 221: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 222
# Frame 222: Detected 2 bounding boxes
# Processed Frame: 223
# Frame 223: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 224
# Frame 224: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 225
# Frame 225: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 226
# Frame 226: Detected 2 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 227
# Frame 227: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 228
# Frame 228: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 229
# Frame 229: Detected 3 bounding boxes
# Processed Frame: 230
# Frame 230: Detected 3 bounding boxes
# Prediction: [1]
# Processed Frame: 231
# Frame 231: Detected 3 bounding boxes
# Prediction: [1]
# Processed Frame: 232
# Frame 232: Detected 2 bounding boxes
# Processed Frame: 233
# Frame 233: Detected 2 bounding boxes
# Processed Frame: 234
# Frame 234: Detected 2 bounding boxes
# Processed Frame: 235
# Frame 235: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 236
# Frame 236: Detected 2 bounding boxes
# Processed Frame: 237
# Frame 237: Detected 1 bounding boxes
# Processed Frame: 238
# Frame 238: Detected 1 bounding boxes
# Prediction: [0]
# Processed Frame: 239
# Frame 239: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 240
# Frame 240: Detected 1 bounding boxes
# Processed Frame: 241
# Frame 241: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 242
# Frame 242: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 243
# Frame 243: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 244
# Frame 244: Detected 1 bounding boxes
# Prediction: [0]
# Processed Frame: 245
# Frame 245: Detected 1 bounding boxes
# Prediction: [0]
# Processed Frame: 246
# Frame 246: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 247
# Frame 247: Detected 1 bounding boxes
# Prediction: [0]
# Processed Frame: 248
# Frame 248: Detected 1 bounding boxes
# Prediction: [0]
# Processed Frame: 249
# Frame 249: Detected 1 bounding boxes
# Prediction: [0]
# Processed Frame: 250
# Frame 250: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 251
# Frame 251: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 252
# Frame 252: Detected 1 bounding boxes
# Processed Frame: 253
# Frame 253: Detected 2 bounding boxes
# Processed Frame: 254
# Frame 254: Detected 3 bounding boxes
# Processed Frame: 255
# Frame 255: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 256
# Frame 256: Detected 1 bounding boxes
# Processed Frame: 257
# Frame 257: Detected 3 bounding boxes
# Processed Frame: 258
# Frame 258: Detected 1 bounding boxes
# Processed Frame: 259
# Frame 259: Detected 1 bounding boxes
# Prediction: [0]
# Processed Frame: 260
# Frame 260: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 261
# Frame 261: Detected 4 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 262
# Frame 262: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 263
# Frame 263: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 264
# Frame 264: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 265
# Frame 265: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 266
# Frame 266: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 267
# Frame 267: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 268
# Frame 268: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 269
# Frame 269: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 270
# Frame 270: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 271
# Frame 271: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 272
# Frame 272: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 273
# Frame 273: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 274
# Frame 274: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 275
# Frame 275: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 276
# Frame 276: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 277
# Frame 277: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 278
# Frame 278: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 279
# Frame 279: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 280
# Frame 280: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 281
# Frame 281: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 282
# Frame 282: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 283
# Frame 283: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 284
# Frame 284: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 285
# Frame 285: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 286
# Frame 286: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 287
# Frame 287: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 288
# Frame 288: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 289
# Frame 289: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 290
# Frame 290: Detected 4 bounding boxes
# Prediction: [0]
# Prediction: [0]
# Processed Frame: 291
# Frame 291: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 292
# Frame 292: Detected 4 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 293
# Frame 293: Detected 4 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 294
# Frame 294: Detected 4 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 295
# Frame 295: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 296
# Frame 296: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 297
# Frame 297: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 298
# Frame 298: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 299
# Frame 299: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 300
# Frame 300: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 301
# Frame 301: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 302
# Frame 302: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 303
# Frame 303: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 304
# Frame 304: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 305
# Frame 305: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 306
# Frame 306: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 307
# Frame 307: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 308
# Frame 308: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 309
# Frame 309: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 310
# Frame 310: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 311
# Frame 311: Detected 3 bounding boxes
# Prediction: [0]
# Processed Frame: 312
# Frame 312: Detected 4 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 313
# Frame 313: Detected 5 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 314
# Frame 314: Detected 4 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 315
# Frame 315: Detected 4 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 316
# Frame 316: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 317
# Frame 317: Detected 4 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 318
# Frame 318: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 319
# Frame 319: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 320
# Frame 320: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 321
# Frame 321: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 322
# Frame 322: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 323
# Frame 323: Detected 2 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 324
# Frame 324: Detected 3 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 325
# Frame 325: Detected 4 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 326
# Frame 326: Detected 4 bounding boxes
# Prediction: [0]
# Prediction: [1]
# Processed Frame: 327
# Frame 327: Detected 4 bounding boxes
# Prediction: [1]
# Prediction: [0]
# Processed Frame: 328
# Frame 328: Detected 3 bounding boxes
# Prediction: [1]
# Prediction: [1]
# Processed Frame: 329

# %%
import os
import smtplib
from email.mime.multipart import MIMEMultipart
from email.mime.text import MIMEText
from email.mime.base import MIMEBase
from email import encoders
from ultralytics import YOLO
import cv2
import xgboost as xgb
import pandas as pd

def send_email_alert(frame_number, confidence, video_path, frame):
    try:
        # SMTP Configuration
        smtp_server = 'smtp.gmail.com'
        smtp_port = 587
        sender_email = "suspicious616@gmail.com"
        sender_password = "fpvk xpog jkfq gjpp"  # Replace with actual app password
        recipient_emails = ['bhuvanm411354@gmail.com', 'suspicious616@gmail.com']
        
        # Email Content
        subject = "🚨 Suspicious Activity Detected!"
        body = (f"Security Alert Notification\n\n"
                f"⚠ Suspicious activity detected in surveillance video\n"
                f"• Video: {os.path.basename(video_path)}\n"
                f"• Frame: {frame_number}\n"
                f"• Confidence: {confidence:.2%}\n\n"
                f"Please review the attached frame immediately.")
        
        # Create MIME Message
        msg = MIMEMultipart()
        msg['From'] = sender_email
        msg['To'] = ", ".join(recipient_emails)
        msg['Subject'] = subject
        msg.attach(MIMEText(body, 'plain'))
        
        # Attach Frame Image
        _, img_encoded = cv2.imencode('.jpg', frame)
        part = MIMEBase('application', 'octet-stream')
        part.set_payload(img_encoded.tobytes())
        encoders.encode_base64(part)
        part.add_header('Content-Disposition', f'attachment; filename="alert_frame_{frame_number}.jpg"')
        msg.attach(part)
        
        # Send Email
        with smtplib.SMTP(smtp_server, smtp_port) as server:
            server.starttls()
            server.login(sender_email, sender_password)
            server.send_message(msg)
        
        print(f"Alert email sent for frame {frame_number} (Confidence: {confidence:.2%})")
        
    except Exception as e:
        print(f"Failed to send email alert: {str(e)}")

def detect_shoplifting(video_path):
    model_yolo = YOLO(r"D:\Final year project\yolo version project\best.pt")
    model = xgb.Booster()
    model.load_model(r"D:\Final year project\yolo version project\model_weights.json")

    cap = cv2.VideoCapture(video_path)
    print('Total Frame', cap.get(cv2.CAP_PROP_FRAME_COUNT))

    fps = int(cap.get(cv2.CAP_PROP_FPS))
    width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
    height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))

    fourcc = cv2.VideoWriter_fourcc('F', 'M', 'P', '4')
    video_name = os.path.splitext(os.path.basename(video_path))[0]
    output_path = fr"D:\Final year project\yolo version project\output video\{video_name}_output.mp4"
    out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

    frame_tot = 0

    while cap.isOpened():
        success, frame = cap.read()

        if success:
            results = model_yolo(frame, verbose=False)
            annotated_frame = results[0].plot(boxes=False)

            for r in results:
                bound_box = r.boxes.xyxy
                conf = r.boxes.conf.tolist()
                keypoints = r.keypoints.xyn.tolist()

                print(f'Frame {frame_tot}: Detected {len(bound_box)} bounding boxes')

                for index, box in enumerate(bound_box):
                    if conf[index] > 0.75:
                        x1, y1, x2, y2 = box.tolist()
                        data = {}

                        for j in range(len(keypoints[index])):
                            data[f'x{j}'] = keypoints[index][j][0]
                            data[f'y{j}'] = keypoints[index][j][1]

                        df = pd.DataFrame(data, index=[0])
                        dmatrix = xgb.DMatrix(df)
                        cut = model.predict(dmatrix)
                        binary_predictions = (cut > 0.5).astype(int)
                        print(f'Prediction: {binary_predictions}')

                        if binary_predictions == 0:  # Suspicious activity
                            conf_text = f'Suspicious ({conf[index]:.2f})'
                            cv2.rectangle(annotated_frame, (int(x1), int(y1)), (int(x2), int(y2)), (255, 7, 58), 2)
                            cv2.putText(annotated_frame, conf_text, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_DUPLEX, 1.0, (255, 7, 58), 2)
                            
                            if conf[index] >= 0.85:  # Only send email for high-confidence detections
                                send_email_alert(frame_tot, conf[index], video_path, annotated_frame)
                                
                        elif binary_predictions == 1:  # Normal activity
                            conf_text = f'Normal ({conf[index]:.2f})'
                            cv2.rectangle(annotated_frame, (int(x1), int(y1)), (int(x2), int(y2)), (57, 255, 20), 2)
                            cv2.putText(annotated_frame, conf_text, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_DUPLEX, 1.0, (57, 255, 20), 2)

            cv2.imshow('Frame', annotated_frame)
            out.write(annotated_frame)
            frame_tot += 1
            print('Processed Frame:', frame_tot)

            if cv2.waitKey(1) & 0xFF == ord("q"):
                break
        else:
            break

    cap.release()
    out.release()
    cv2.destroyAllWindows()

# Example usage:
video_path = r"D:\Final year project\yolo version project\10480748-uhd_4096_2160_25fps.mp4"
detect_shoplifting(video_path)
# Out:
# Total Frame 1072.0
# Frame 0: Detected 2 bounding boxes
# Processed Frame: 1
# Frame 1: Detected 2 bounding boxes
# Processed Frame: 2
# Frame 2: Detected 2 bounding boxes
# Processed Frame: 3
# Frame 3: Detected 2 bounding boxes
# Processed Frame: 4
# Frame 4: Detected 2 bounding boxes
# Processed Frame: 5
# Frame 5: Detected 2 bounding boxes
# Processed Frame: 6
# Frame 6: Detected 2 bounding boxes
# Processed Frame: 7
# Frame 7: Detected 2 bounding boxes
# Processed Frame: 8
# Frame 8: Detected 2 bounding boxes
# Processed Frame: 9
# Frame 9: Detected 2 bounding boxes
# Processed Frame: 10
# Frame 10: Detected 2 bounding boxes
# Processed Frame: 11
# Frame 11: Detected 2 bounding boxes
# Processed Frame: 12
# Frame 12: Detected 2 bounding boxes
# Processed Frame: 13
# Frame 13: Detected 2 bounding boxes
# Processed Frame: 14
# Frame 14: Detected 2 bounding boxes
# Processed Frame: 15
# Frame 15: Detected 2 bounding boxes
# Processed Frame: 16
# Frame 16: Detected 2 bounding boxes
# Processed Frame: 17
# Frame 17: Detected 2 bounding boxes
# Processed Frame: 18
# Frame 18: Detected 2 bounding boxes
# Processed Frame: 19
# Frame 19: Detected 1 bounding boxes
# Processed Frame: 20
# Frame 20: Detected 1 bounding boxes
# Processed Frame: 21
# Frame 21: Detected 1 bounding boxes
# Processed Frame: 22
# Frame 22: Detected 1 bounding boxes
# Processed Frame: 23
# Frame 23: Detected 1 bounding boxes
# Processed Frame: 24
# Frame 24: Detected 2 bounding boxes
# Processed Frame: 25
# Frame 25: Detected 2 bounding boxes
# Processed Frame: 26
# Frame 26: Detected 1 bounding boxes
# Processed Frame: 27
# Frame 27: Detected 1 bounding boxes
# Processed Frame: 28
# Frame 28: Detected 1 bounding boxes
# Processed Frame: 29
# Frame 29: Detected 1 bounding boxes
# Processed Frame: 30
# Frame 30: Detected 1 bounding boxes
# Processed Frame: 31
# Frame 31: Detected 2 bounding boxes
# Processed Frame: 32
# Frame 32: Detected 1 bounding boxes
# Processed Frame: 33
# Frame 33: Detected 1 bounding boxes
# Processed Frame: 34
# Frame 34: Detected 2 bounding boxes
# Processed Frame: 35
# Frame 35: Detected 2 bounding boxes
# Processed Frame: 36
# Frame 36: Detected 1 bounding boxes
# Processed Frame: 37
# Frame 37: Detected 1 bounding boxes
# Processed Frame: 38
# Frame 38: Detected 2 bounding boxes
# Processed Frame: 39
# Frame 39: Detected 1 bounding boxes
# Processed Frame: 40
# Frame 40: Detected 1 bounding boxes
# Processed Frame: 41
# Frame 41: Detected 3 bounding boxes
# Processed Frame: 42
# Frame 42: Detected 3 bounding boxes
# Processed Frame: 43
# Frame 43: Detected 3 bounding boxes
# Processed Frame: 44
# Frame 44: Detected 3 bounding boxes
# Processed Frame: 45
# Frame 45: Detected 2 bounding boxes
# Processed Frame: 46
# Frame 46: Detected 3 bounding boxes
# Processed Frame: 47
# Frame 47: Detected 4 bounding boxes
# Processed Frame: 48
# Frame 48: Detected 4 bounding boxes
# Processed Frame: 49
# Frame 49: Detected 4 bounding boxes
# Processed Frame: 50
# Frame 50: Detected 4 bounding boxes
# Processed Frame: 51
# Frame 51: Detected 4 bounding boxes
# Processed Frame: 52
# Frame 52: Detected 3 bounding boxes
# Processed Frame: 53
# Frame 53: Detected 3 bounding boxes
# Processed Frame: 54
# Frame 54: Detected 3 bounding boxes
# Processed Frame: 55
# Frame 55: Detected 2 bounding boxes
# Processed Frame: 56
# Frame 56: Detected 3 bounding boxes
# Processed Frame: 57
# Frame 57: Detected 2 bounding boxes
# Processed Frame: 58
# Frame 58: Detected 3 bounding boxes
# Processed Frame: 59
# Frame 59: Detected 3 bounding boxes
# Processed Frame: 60
# Frame 60: Detected 3 bounding boxes
# Prediction: [1]
# Processed Frame: 61
# Frame 61: Detected 3 bounding boxes
# Processed Frame: 62
# Frame 62: Detected 2 bounding boxes
# Processed Frame: 63
# Frame 63: Detected 2 bounding boxes
# Processed Frame: 64
# Frame 64: Detected 2 bounding boxes
# Processed Frame: 65
# Frame 65: Detected 2 bounding boxes
# Processed Frame: 66
# Frame 66: Detected 2 bounding boxes
# Processed Frame: 67
# Frame 67: Detected 2 bounding boxes
# Processed Frame: 68
# Frame 68: Detected 2 bounding boxes
# Processed Frame: 69
# Frame 69: Detected 2 bounding boxes
# Processed Frame: 70
# Frame 70: Detected 2 bounding boxes
# Processed Frame: 71
# Frame 71: Detected 2 bounding boxes
# Processed Frame: 72
# Frame 72: Detected 1 bounding boxes
# Processed Frame: 73
# Frame 73: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 74
# Frame 74: Detected 1 bounding boxes
# Processed Frame: 75
# Frame 75: Detected 1 bounding boxes
# Processed Frame: 76
# Frame 76: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 77
# Frame 77: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 78
# Frame 78: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 79
# Frame 79: Detected 1 bounding boxes
# Processed Frame: 80
# Frame 80: Detected 1 bounding boxes
# Processed Frame: 81
# Frame 81: Detected 1 bounding boxes
# Processed Frame: 82
# Frame 82: Detected 1 bounding boxes
# Processed Frame: 83
# Frame 83: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 84
# Frame 84: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 85
# Frame 85: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 86
# Frame 86: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 87
# Frame 87: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 88
# Frame 88: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 89
# Frame 89: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 90
# Frame 90: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 91
# Frame 91: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 92
# Frame 92: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 93
# Frame 93: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 94
# Frame 94: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 95
# Frame 95: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 96
# Frame 96: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 97
# Frame 97: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 98
# Frame 98: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 99
# Frame 99: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 100
# Frame 100: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 101
# Frame 101: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 102
# Frame 102: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 103
# Frame 103: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 104
# Frame 104: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 105
# Frame 105: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 106
# Frame 106: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 107
# Frame 107: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 108
# Frame 108: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 109
# Frame 109: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 110
# Frame 110: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 111
# Frame 111: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 112
# Frame 112: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 113
# Frame 113: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 114
# Frame 114: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 115
# Frame 115: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 116
# Frame 116: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 117
# Frame 117: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 118
# Frame 118: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 119
# Frame 119: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 120
# Frame 120: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 121
# Frame 121: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 122
# Frame 122: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 123
# Frame 123: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 124
# Frame 124: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 125
# Frame 125: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 126
# Frame 126: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 127
# Frame 127: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 128
# Frame 128: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 129
# Frame 129: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 130
# Frame 130: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 131
# Frame 131: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 132
# Frame 132: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 133
# Frame 133: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 134
# Frame 134: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 135
# Frame 135: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 136
# Frame 136: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 137
# Frame 137: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 138
# Frame 138: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 139
# Frame 139: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 140
# Frame 140: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 141
# Frame 141: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 142
# Frame 142: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 143
# Frame 143: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 144
# Frame 144: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 145
# Frame 145: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 146
# Frame 146: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 147
# Frame 147: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 148
# Frame 148: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 149
# Frame 149: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 150
# Frame 150: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 151
# Frame 151: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 152
# Frame 152: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 153
# Frame 153: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 154
# Frame 154: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 155
# Frame 155: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 156
# Frame 156: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 157
# Frame 157: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 158
# Frame 158: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 159
# Frame 159: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 160
# Frame 160: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 161
# Frame 161: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 162
# Frame 162: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 163
# Frame 163: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 164
# Frame 164: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 165
# Frame 165: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 166
# Frame 166: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 167
# Frame 167: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 168
# Frame 168: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 169
# Frame 169: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 170
# Frame 170: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 171
# Frame 171: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 172
# Frame 172: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 173
# Frame 173: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 174
# Frame 174: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 175
# Frame 175: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 176
# Frame 176: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 177
# Frame 177: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 178
# Frame 178: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 179
# Frame 179: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 180
# Frame 180: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 181
# Frame 181: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 182
# Frame 182: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 183
# Frame 183: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 184
# Frame 184: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 185
# Frame 185: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 186
# Frame 186: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 187
# Frame 187: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 188
# Frame 188: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 189
# Frame 189: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 190
# Frame 190: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 191
# Frame 191: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 192
# Frame 192: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 193
# Frame 193: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 194
# Frame 194: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 195
# Frame 195: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 196
# Frame 196: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 197
# Frame 197: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 198
# Frame 198: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 199
# Frame 199: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 200
# Frame 200: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 201
# Frame 201: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 202
# Frame 202: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 203
# Frame 203: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 204
# Frame 204: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 205
# Frame 205: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 206
# Frame 206: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 207
# Frame 207: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 208
# Frame 208: Detected 2 bounding boxes
# Prediction: [0]
# Processed Frame: 209
# Frame 209: Detected 2 bounding boxes
# Processed Frame: 210
# Frame 210: Detected 2 bounding boxes
# Processed Frame: 211
# Frame 211: Detected 2 bounding boxes
# Processed Frame: 212
# Frame 212: Detected 2 bounding boxes
# Prediction: [1]
# Processed Frame: 213
# Frame 213: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 214
# Frame 214: Detected 1 bounding boxes
# Prediction: [1]
# Processed Frame: 215
# Frame 215: Detected 1 bounding boxes
# Prediction: [0]
# Processed Frame: 216
# Frame 216: Detected 1 bounding boxes
# Prediction: [0]
# Alert email sent for frame 216 (Confidence: 86.11%)
# Processed Frame: 217
# Frame 217: Detected 1 bounding boxes
# Prediction: [0]
# Alert email sent for frame 217 (Confidence: 85.68%)
# Processed Frame: 218
# Frame 218: Detected 1 bounding boxes
# Prediction: [0]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 133
#     131 # Example usage:
#     132 video_path = r"D:\Final year project\yolo version project\10480748-uhd_4096_2160_25fps.mp4"
# --> 133 detect_shoplifting(video_path)
#
# Cell In[2], line 110, in detect_shoplifting(video_path)
#     107     cv2.putText(annotated_frame, conf_text, (int(x1), int(y1) - 10), cv2.FONT_HERSHEY_DUPLEX, 1.0, (255, 7, 58), 2)
#     109     if conf[index] >= 0.85:  # Only send email for high-confidence detections
# --> 110         send_email_alert(frame_tot, conf[index], video_path, annotated_frame)
#     112 elif binary_predictions == 1:  # Normal activity
#     113     conf_text = f'Normal ({conf[index]:.2f})'
#
# Cell In[2], line 46, in send_email_alert(frame_number, confidence, video_path, frame)
#      43 msg.attach(part)
#      45 # Send Email
# ---> 46 with smtplib.SMTP(smtp_server, smtp_port) as server:
#      47     server.starttls()
#      48     server.login(sender_email, sender_password)
#
# File ~\AppData\Local\Programs\Python\Python39\lib\smtplib.py:255, in SMTP.__init__(self, host, port, local_hostname, timeout, source_address)
#     252 self._auth_challenge_count = 0
#     254 if host:
# --> 255     (code, msg) = self.connect(host, port)
#     256     if code != 220:
#     257         self.close()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\smtplib.py:343, in SMTP.connect(self, host, port, source_address)
#     341 self.sock = self._get_socket(host, port, self.timeout)
#     342 self.file = None
# --> 343 (code, msg) = self.getreply()
#     344 if self.debuglevel > 0:
#     345     self._print_debug('connect:', repr(msg))
#
# File ~\AppData\Local\Programs\Python\Python39\lib\smtplib.py:398, in SMTP.getreply(self)
#     396 while 1:
#     397     try:
# --> 398         line = self.file.readline(_MAXLINE + 1)
#     399     except OSError as e:
#     400         self.close()
#
# File ~\AppData\Local\Programs\Python\Python39\lib\socket.py:704, in SocketIO.readinto(self, b)
#     702 while True:
#     703     try:
# --> 704         return self._sock.recv_into(b)
#     705     except timeout:
#     706         self._timeout_occurred = True
#
# KeyboardInterrupt:
